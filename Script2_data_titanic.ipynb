# %%
#importation the librairy of pandas and os
import pandas as pd
import os

# %%
#loading a csv file
excel_link = './Downloads/titanic.csv'
df= pd.read_csv(excel_link)

# %%
#showing the data frame 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#showing a list of columns for data frame
df_columns = df.columns
list(df_columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
#dropping the columns that we don't need for our analysing
columns_drop=['Pclass', 'Name', 'Ticket', 'Fare','Cabin','Embarked']
df=df.drop(columns = columns_drop)
df
# Out:
#      PassengerId  Survived     Sex   Age  SibSp  Parch
# 0              1         0    male  22.0      1      0
# 1              2         1  female  38.0      1      0
# 2              3         1  female  26.0      0      0
# 3              4         1  female  35.0      1      0
# 4              5         0    male  35.0      0      0
# ..           ...       ...     ...   ...    ...    ...
# 886          887         0    male  27.0      0      0
# 887          888         1  female  19.0      0      0
# 888          889         0  female   NaN      1      2
# 889          890         1    male  26.0      0      0
# 890          891         0    male  32.0      0      0
#
# [891 rows x 6 columns]

# %%
#combine SibSp and Parch in one columns name's TotalFamily
df['TotalFamily'] = df['SibSp'] + df['Parch']
df
# Out:
#      PassengerId  Survived     Sex   Age  SibSp  Parch  TotalFamily
# 0              1         0    male  22.0      1      0            1
# 1              2         1  female  38.0      1      0            1
# 2              3         1  female  26.0      0      0            0
# 3              4         1  female  35.0      1      0            1
# 4              5         0    male  35.0      0      0            0
# ..           ...       ...     ...   ...    ...    ...          ...
# 886          887         0    male  27.0      0      0            0
# 887          888         1  female  19.0      0      0            0
# 888          889         0  female   NaN      1      2            3
# 889          890         1    male  26.0      0      0            0
# 890          891         0    male  32.0      0      0            0
#
# [891 rows x 7 columns]

# %%
#dropping the two columns SibSp and Parch bcs we don't need them
df_drop_fam = ['SibSp','Parch']
df = df.drop(columns=df_drop_fam)
df
# Out:
#      PassengerId  Survived     Sex   Age  TotalFamily
# 0              1         0    male  22.0            1
# 1              2         1  female  38.0            1
# 2              3         1  female  26.0            0
# 3              4         1  female  35.0            1
# 4              5         0    male  35.0            0
# ..           ...       ...     ...   ...          ...
# 886          887         0    male  27.0            0
# 887          888         1  female  19.0            0
# 888          889         0  female   NaN            3
# 889          890         1    male  26.0            0
# 890          891         0    male  32.0            0
#
# [891 rows x 5 columns]

# %%
#dropping the rows in survived columns that have a missing values
df['Survived'].dropna(axis=0, inplace=True)
df #we see that we don't have a missing values in survived columns
# Out:
#      PassengerId  Survived     Sex   Age  TotalFamily
# 0              1         0    male  22.0            1
# 1              2         1  female  38.0            1
# 2              3         1  female  26.0            0
# 3              4         1  female  35.0            1
# 4              5         0    male  35.0            0
# ..           ...       ...     ...   ...          ...
# 886          887         0    male  27.0            0
# 887          888         1  female  19.0            0
# 888          889         0  female   NaN            3
# 889          890         1    male  26.0            0
# 890          891         0    male  32.0            0
#
# [891 rows x 5 columns]

# %%
#converting a female to number 0 and male to number 1
df['Sex'] = df['Sex'].replace({'female': 0, 'male': 1})
df
# Out:
#      PassengerId  Survived  Sex   Age  TotalFamily
# 0              1         0    1  22.0            1
# 1              2         1    0  38.0            1
# 2              3         1    0  26.0            0
# 3              4         1    0  35.0            1
# 4              5         0    1  35.0            0
# ..           ...       ...  ...   ...          ...
# 886          887         0    1  27.0            0
# 887          888         1    0  19.0            0
# 888          889         0    0   NaN            3
# 889          890         1    1  26.0            0
# 890          891         0    1  32.0            0
#
# [891 rows x 5 columns]

# %%
#sauvgarding this data frame in excel file name's titanic01
df.to_excel('titanic01.xlsx', index=False)

# %%
#impoti a lybrairie matplotlib for visualization the data
import matplotlib.pyplot as plt
# Group the data by the 'Survived' column and count the number of occurrences
survived_counts = df['Survived'].value_counts()
# Create a bar plot to visualize the number of people who survived
plt.bar(survived_counts.index, survived_counts.values)
plt.xlabel('Survived')
plt.ylabel('Number of people')
plt.title('Number of People who Survived')
plt.xticks(survived_counts.index, ['No', 'Yes'])  # Assuming 'Survived' column has values 0 and 1
plt.show()

# %%
#visualization the sex distribution with pie chart
sex_counts = df['Sex'].value_counts()
sizes = sex_counts  # Sizes of the sectors
labels = ['Female', 'Male']  # Labels for the sectors
colors = ['pink', 'lightblue']  # Colors for the sectors

# Create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures a circular shape
plt.title('Sex Distribution')

# Display the chart
plt.show()

# %%
#minimum of age
df['Age'].min()
# Out:
# 0.42

# %%
#maximum of age
df['Age'].max()
# Out:
# 80.0

# %%
#average of age
df_Age_avg = df['Age'].mean()
df_Age_avg_int = df_Age_avg.round().astype(int)
df_Age_avg_int
# Out:
# 30

# %%
#people less than 30yrs/survival
df_Age_Srvd_count_less = df[(df['Age']<=30) & (df['Survived'] == 1)].shape[0]
df_Age_Srvd_count_less
# Out:
# 166

# %%
#people less than 30yrs/not survived
df_Age_nSrvd_count_less = df[(df['Age']<=30) & (df['Survived'] == 0)].shape[0]
df_Age_nSrvd_count_less
# Out:
# 243

# %%
#409 personne less than 30yrs
minage=df['Age']<=30
minage.value_counts()
# Out:
# False    482
# True     409
# Name: Age, dtype: int64

# %%
sizes = [df_Age_Srvd_count_less,df_Age_nSrvd_count_less ] # Sizes of the sectors
labels = ['Survived', 'Died']  # Labels for the sectors
colors = ['green', 'red']  # Colors for the sectors

# Create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures a circular shape
plt.title('Survived By Age less than 30yrs')

# Display the chart
plt.show()

# %%
#people more than 30yrs/survival
df_Age_Srvd_count_more = df[(df['Age']>30) & (df['Survived'] == 1)].shape[0]
df_Age_Srvd_count_more
# Out:
# 124

# %%
#people more than 30yrs/not survived
df_Age_nSrvd_count_more = df[(df['Age']>30) & (df['Survived'] == 0)].shape[0]
df_Age_nSrvd_count_more
# Out:
# 181

# %%
sizes = [df_Age_Srvd_count_more,df_Age_nSrvd_count_more] # Sizes of the sectors
labels = ['Survived', 'Died']  # Labels for the sectors
colors = ['green', 'red']  # Colors for the sectors

# Create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures a circular shape
plt.title('Survived By Age More than 30yrs')

# Display the chart
plt.show()

# %%
#305 personne more than 30yrs
maxage=df['Age']>30
maxage.value_counts()
# Out:
# False    586
# True     305
# Name: Age, dtype: int64

# %%
# Calculate the total family size
total_family_size = df['TotalFamily'].sum()

# Plot the total family size
plt.bar('Total Family', total_family_size)

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Family Size')
plt.title('Total Family Size')

# Display the chart
plt.show()

# %%
# Analyze survival rates for passengers traveling alone vs. with family
alone_survived = df.loc[(df['TotalFamily'] == 0) & (df['Survived'] == 1)]
alone_not_survived = df.loc[(df['TotalFamily'] == 0) & (df['Survived'] == 0)]
with_family_survived = df.loc[(df['TotalFamily'] > 1) & (df['Survived'] == 1)]
with_family_not_survived = df.loc[(df['TotalFamily'] > 1) & (df['Survived'] == 0)]

# Calculate survival rates
alone_survival_rate = len(alone_survived) / len(df.loc[df['TotalFamily'] == 0])
with_family_survival_rate = len(with_family_survived) / len(df.loc[df['TotalFamily'] > 1])

# Plotting the survival rates
labels = ['Alone', 'With Family']
survival_rates = [alone_survival_rate, with_family_survival_rate]

plt.bar(labels, survival_rates)
plt.xlabel('Passenger Type')
plt.ylabel('Survival Rate')
plt.title('Survival Rate: Alone vs. With Family')
